# %%
from nse_data import NSEData
from Database import DatabaseHandler

# %%
db = DatabaseHandler()

# %%
reliance_df = db.fetch_data_by_symbol(symbol="RELIANCE")
# Out:
# Data for symbol 'RELIANCE' fetched successfully.

# %%
reliance_df
# Out:
#         Symbol Series        Date Prev_Close Open_Price High_Price Low_Price  \
# 0     RELIANCE     EQ  2015-01-01     891.15      886.3      892.0    883.65
# 1     RELIANCE     EQ  2015-01-02      887.9      888.1     896.05     884.3
# 2     RELIANCE     EQ  2015-01-05     885.55      885.0      890.9     874.1
# 3     RELIANCE     EQ  2015-01-06     875.85      870.0      873.0     832.0
# 4     RELIANCE     EQ  2015-01-07      836.1      837.1      858.8     837.0
# ...        ...    ...         ...        ...        ...        ...       ...
# 2425  RELIANCE     EQ  2024-10-18   2,712.85   2,704.35   2,736.85  2,682.65
# 2426  RELIANCE     EQ  2024-10-21   2,718.60   2,734.25   2,748.00  2,715.45
# 2427  RELIANCE     EQ  2024-10-22   2,738.40   2,738.40   2,752.00  2,680.45
# 2428  RELIANCE     EQ  2024-10-23   2,686.70   2,675.00   2,714.95  2,670.00
# 2429  RELIANCE     EQ  2024-10-24   2,677.05   2,670.55   2,687.40  2,646.25
#
# ...
